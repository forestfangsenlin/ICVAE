# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch

from rdkit.Chem.Descriptors import ExactMolWt
from rdkit.Chem.Crippen import MolLogP
from rdkit.Chem.rdMolDescriptors import CalcNumHBD    
from rdkit.Chem.rdMolDescriptors import CalcNumHBA
from rdkit.Chem.rdMolDescriptors import CalcTPSA
from rdkit import Chem
from rdkit.Chem.QED import qed
from utils import decode_smiles_from_indexes, load_dataset

from model import MolecularICVAE
from rdkit import RDLogger   
RDLogger.DisableLog('rdApp.*')

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = MolecularICVAE().to(device)

# %%
model.load_state_dict(torch.load('./result/model/MW_model.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Warning
# **please note because the input value should be the normalized property value ranging from 0 to 500. So you need to change the true property value to normalized property firstly. In the following, we give you the two value y.min() and y_range = (y.max()-y.min()) for esily change:**
#
#
# MW: [150.025169192,          201.12958056818]
#
# SAS: [1.0574495523703487,  6.351893861381157]
#
# TPSA: [0.,                149.48999999999998]
#
# logP: [-4.9017,           10.970920000000003]
#
# QED: [0.2335469098782191, 0.7145762918458708]
#
# HBA: [0,                                  10]
#
# HBD: [0,                                   5]

# %%
 def reconstructed(autoencoder, charset, p1):
    valid_smile = []
    
    p1 = (p1 - 150.025169192)/201.12958056818*500
    ## the two value 150.025169192 and 201.12958056818 need to change if you use want to generate other property.

    nums = 1000
    x = np.linspace(0, 10, 33)

    prop_np  = np.zeros((nums, 128))
    prop_np[:,0:2] = np.ones((nums,2))*p1
    
    p_ar = np.array([p1])
    p = np.repeat(p_ar[:], nums,0)
    for i in range(1000):
        
        lat =  np.random.normal(0., 1., size=(nums, 128)).astype ('float32')    
        lat = lat + prop_np
                
        lat_torch =  torch.Tensor(lat).to(device)
        cond_torch =  torch.Tensor(p).to(device)
        
        output = autoencoder.decode(lat_torch, cond_torch)
        outp = output.cpu().detach().numpy()
        
        for j in range(nums):
            decode_smi = outp[j].reshape(1, 120, len(charset)).argmax(axis=2)[0]
            smi = decode_smiles_from_indexes(decode_smi, charset)
            m = Chem.MolFromSmiles(smi)
            #if (m != None) and (' ' not in smi) and (abs(ExactMolWt(m)-p1)<10*2)  and (abs(MolLogP(m)-p2)<0.548546*2)  and (abs(calculateScore(m)-p3)<0.3176*2) and (abs(qed(m)-p4)<0.0357*2) and (abs(CalcNumHBA(m)-p5)<1*2) and (abs(CalcNumHBD(m)-p6)<1*2)and (abs(CalcTPSA(m)-p7)<7.47*2):
            if (m != None) and (' ' not in smi):
                valid_smile.append(smi)
                
    valid_smile = list(set(valid_smile))
 
    return valid_smile

# %% [markdown]
# ### Sampling by setting the lantent value (condition) at 210

# %%
lines = []
valid_smile_all = []

condition = 210
## set the condition value (MW value) 
X_train, X_test, charset = load_dataset('./data/processed.h5')
valid_smile = reconstructed(model, charset, condition)

# %%
valid_smile
# Out:
# ['CCCCCCCCCCCCOOOCCCCCCCC',
#  'CC(C)CCC1CcCCC1',
#  'Cc1cccnnn1BBBC',
#  'C[C@@H]CCCCCCCCCCCCCCCOOO',
#  'C1cccccc1NBOOO',
#  'CCOC(=O)c1ccccccc1BB',
#  'C[C@@H]CCCOOCCCCCCCC',
#  'CCCCCCCCCCCCCCCOOOO',
#  'CC1CCCCCCC1CCCSS',
#  'c1ccccccc1CCCCCCCCCOOOO',
#  'CNNCCCCCCCCCCCCCCCCOOOOOO',
#  'CC(CCCCCCCCCCCCCCCC)CCCCC',
#  'c1ccccccc1NCCCCCCCC',
#  'CC1CC=C1CCCCSSCC',
#  'Cc1ccccc1c2ccccc2CCCCOOO',
#  'C[C@@H]1cccccc1CNCCCO',
#  'c1ccc(cc1SSS(SO))N',
#  'CC(C)CCCCCOOCCCCCOO(OO)',
#  'CCC=CCCCCCCCCCCCCCCCC',
#  'CC(C(=O)CCCCCCCCCCC)C',
#  'Cc1ccccccccccc1CC',
#  'c1ccc(cc1S2ccccoo2)',
#  'CC(C(CCCCCCCCCCOO))OCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCCCOO',
#  'CC(CC)CCCCCCCCCCCCCOOO',
#  'c1ccc(cc1)CCCCCCCCCCCCCCOOOOOO',
#  'CCCCCCCCCCCCCCCCCCCCCCCO',
#  'CCCCCCCCCCCCCCSS',
#  'c1cc(ccc1SSS(S))NNN',
#  'CCCCCCCCCC(C)CCCCCCCCCC',
#  'c1ccccccc1COOOOOCCO',
#  'CNC=CCCCCCCCCCC',
#  'CCCCCC(CCCCCCCCCCCCCCC)',
#  'c1ccc2cc1cccnnnnnn2S#CCCC',
#  'CCOC(OO)CCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCCC',
#  'C1cccccc1CCCOOOOO',
#  'CC(C)CCCCCOOCCCCC(OOO)O',
#  'Cc1c(nno1)BBBNNNN',
#  'c1ccc2c(c1)cccccnncccnnn2CCCCCCC',
#  'CCCCCCCCCCCCCSCCC',
#  'CC1CC(CCO1)CCCCCCCCCCC',
#  'CCOc1ccccccccc1C',
#  'C1cccccccc1CCCCC',
#  'CCOCOOOc1ccccccccc1',
#  'c1ccc(cc1)COOCCCCCCCCCCCCCCOOO',
#  'CCCCOCCCCCCCCCCCCCC',
#  'c1ccc2ccc1ccccccccccccc2',
#  'c1cccCcc1NCCCCCCCCCNN',
#  'c1ccc(cc1)C(O)Nc2ccccc2CCCCCCCC',
#  'CCOc1cccccccccc11OON1',
#  'c1ccc(cc1)CCCCCCCCCOOOOON',
#  'CC1cccccccccccc1NS',
#  'Cc1cccc(c1C)CCCCCCCCCCCCCCCC',
#  'Cc1ccccccccccc1O',
#  'CCOCOONCCCCCCCCOOOO',
#  'c1ccc(cc1)CC2ccccccccccccnn2',
#  'Cc1ccnnnnnnccccccc1CCC',
#  'C1CCC(CC1)CCCCCCCCCCCCCC3CC3',
#  'C1ccCcc(n1CCCCCCCCCCCCCC)',
#  'CCNCNNNCCCCCCCCCCCCOO',
#  'C1NNNNCC1CCCCCCCCCCOOOOOO',
#  'Cc1ccccccccccccc1CCCCCCCCCCC',
#  'Cc1ccccccc1BCC',
#  'CC(C(CCCC1cccccc1))OOOCC',
#  'C1cccccc1CCCCCCCCCOO',
#  'Cc1c(nno1)CCCCCCCCCC',
#  'CCCCNNNCCCCCCCCCCO',
#  'C[C@@H]CCCCCCCSCCCCCC',
#  'CCCCCONCCCCCCCCCOOOO',
#  'c1cc(ccc1C(OOO))NN',
#  'c1ccc(cc1CCCOOO)CCCCCCCCC',
#  'Cc1ccccccccccc1B',
#  'C[C@@H]CCCCCCCCCCCCCCl',
#  'Cc1ccc(cc1B)CCCOOO',
#  'c1ccc(c(c1)CCCCCC)CCCCCC',
#  'c1ccc(cc1)C2ccc3ccccccc32',
#  'CC(=O)CCC1cccc1OOOOO',
#  'Cc1c(nno1)CCNNNNOC2CCCCC2',
#  'CC1(nnnncccc(C1C))',
#  'Cc1ccccccc1NCCCOCCCC',
#  'C1CCCNC1CCCCCCCC',
#  'c1ccc(cc1)CCNNNCCCC',
#  'Cc1ccnnc1(BCCCOO)',
#  'c1ccc(cc1)CCCCCCCCCCCO',
#  'CCC1Occcccc1CCCCCOOO',
#  'CC(C(CO)CCCCCCCC)',
#  'Cc1ccccc1NCCOOOO',
#  'C[C@@H]CCCCCCCCCCCC',
#  'C1CCCCCC1CCCCCCCCCCCCCCCCCCF',
#  'C1ccc(nnn1)CCCCCCCCCCC',
#  'C[C@@H]CCCCCCCCCOOOOC',
#  'Cc1cc(no1)CC(OO)c2ccccc2CC',
#  'CCCCCCCCCCOCCCCCCCCCCCCC',
#  'c1ccccccc1COOOOOCCCCCCCC',
#  'Cc1c(nnonn1)CCCCCC',
#  'CC1cccccc1CCCCC',
#  'Cc1c2cccccccccc1cccc2CCC',
#  'c1ccccccc1CCCCCC',
#  'Cc1ccccccccnnn1',
#  'c1ccccnn1CCCCCN',
#  'Cc1ccc2ccccc2nn1CCCCCCCCCCCCCC',
#  'CCCCCCCC1ccccN1',
#  'CCCC1cccccc1CCCCCCC',
#  'CCOC(=O)CC1nnnnnnnnC1',
#  'CCNNCCCCCCCCCCCCCCCCCCCCCCCl',
#  'CC1COcccccc1NNN',
#  'Cc1ccccccccccccc1CCCCCCCC',
#  'Cc1ccccc1NNNNCCCCCC',
#  'C1NCCNc1CCCCCCCCC',
#  'c1cccccn1CCNNCCCCCCC',
#  'Cc1ccccccc1CCCCCCCCCCNN',
#  'c1ccc(cc1)NNNNCCCCC2CCCCC2',
#  'C[C@@H]CC1cccccccccc1',
#  'c1ccc2ccc1ccccccccccccccccc2',
#  'CCNCC=CCCCCCCCCCCCCCCCCCCCCCCCCC',
#  'CCOC(=O)CC1CCCCC1OO',
#  'CC1CCCCCC1CCCCCCCCCCCCCOO',
#  'CCCCCCCCCCCCCCCCCCCC=O',
#  'CCOCCOCCCCCCCCCCCCCCCC',
#  'c1cc(ccc1CCCCCCCC)OONN',
#  'C1CCCCCC1CCCCCC',
#  'c1ccc(cc1)c2ccccc2CCN',
#  'CCCC(=O)CCCCCCCCCCCCCCCCCCCCCO',
#  'C1cccccccc1C(CO)OCCCCCCCCCCCCCCCC',
#  'c1ccc(cc1)CNNCCCCCC',
#  'CC(=O)c1ccccc1OOOCCCCCC',
#  'CC(CCCC)CCCCCCCCCCCC',
#  'CCCCCCCCCCCCCSSOOO',
#  'C1CcCCC1CCCCCCCCCCCCCCOOOO',
#  'c1ccc(cc1)CCC2cccccccccc2',
#  'C1cccc(cc1)CCCCCCCCCCNN',
#  'Cc1cccccccccccccnnnn1',
#  'CC(C(CCCCC(CCCCOO)))CCCCCC',
#  'CC1CCCCCC1=CNS',
#  'CCOC(OC=CCCCCCCCCCCCCCCC)C',
#  'C[C@@H]CCCCCCCCS',
#  'CC1=c(cccccccccc1)CCOOOO',
#  'Cc1cccnnn1CCCCCCCCCCCCC',
#  'c1ccccccc1CCCCCCCCCCOO',
#  'C[C@@H]CCCCCCCCCCCCCCCCCC',
#  'c1ccc(cc1)CCOOONNCCCCCCCC',
#  'CNCCCCCCCCCCCCCCCCCOO',
#  'c1ccccccc1CCCCCCCOOOOOO',
#  'C[C@@H]CCCCCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCSS',
#  'Cc1cccnnn1CCCC=CCCCC',
#  'Cc1ccccc1CCCOOOOOCCCCC',
#  'c1ccccccc1CCCCCCCCCOO',
#  'CC(C)CCCCCCCCCCCOCCCCCCCCCC',
#  'C1CCCCCC1CCCCCCCCCCCCCCCCCCCCCCC',
#  'CC(C)CCCCC1Ccccccccc1',
#  'C1cc(c(c1))CCCCCCCCC#C',
#  'Cc1ccccccccccnn1BBNN',
#  'CCOC(=O)CCCCCCCCCC',
#  'Cc1cccc(c1)c2ncnnnnn2',
#  'Cc1cccnnnccccccc1CCC',
#  'c1ccccccc1CCCOOOOCOO',
#  'c1ccc2c(c1)cccccccccccccccc2',
#  'CCOC(=O)CC1CCCC1O',
#  'CCNc1ccccccccc1CCC',
#  'CCCCCCCCCCCCCCCC1OO1',
#  'c1ccc(cc1CCCCCCCC)OOOOOOON',
#  'c1ccc(cc1)CCCCCCCCCCCOOOOO',
#  'c1ccc(cc1)CCOOOCCCCCCCC',
#  'CC1cccccccccc1',
#  'CC(C)CCCCCCCCCCCCCCCOOO',
#  'c1ccccccc1CCCCCCCCCCCCCOOOOOO',
#  'C1ccccc(c1)CCCCCCCCCCCCCCCCCC',
#  'CC1ccccccccccC1CNN',
#  'c1cCCCCCCCCCCCCC1O',
#  'CCOC(=O)CCCC1CCC1OOO',
#  'C[C@@H]CCCCCCCCCCCCCCCCCCCCC',
#  'Cc1cccnncc1CC',
#  'CCCC(=O)CCCNCCCCCCCCOOOO',
#  'Cc1ccccc1OOCOOOOOCC',
#  'C1cccccc1NCCOOOCCCC',
#  'c1cc(oc1)COOOON2ccccC2N',
#  'c1ccccccc1CCCCCCCCCCCCCC',
#  'Cc1ccccc1CC(OO)c2ccccc2',
#  'CCCCCCCCCCCCCCCCCCOOOOO',
#  'CC1(OOOcccccccccccccc1)O',
#  'CCC=CCCCCCCCCCCCCCCCCCCCCCCCCC',
#  'c1ccccccc1CCCCNNNNN',
#  'c1cccocc1S2nnnno2NN',
#  'c1ccc2ccc12CCCCCCCC',
#  'Cc1ccccccccccc1CCCCCNN',
#  'c1cc(ccc1n2nnnnn2N)',
#  'CCCCCCCCCCCCCC=CCCCOO',
#  'Cc1cccnnnccccc1C',
#  'CCCC(ON)CCCCCCCCCCCOOOO',
#  'Cc1cccnnnnnnnnn1CCCCC',
#  'c1ccccccc1CCCCCCCCCOOO',
#  'c1ccc(cc1CCCC)CCCCCCCCCOOOOO',
#  'C1CCCCCCCCCCCCCCC1CC',
#  'Cc1ccccccccccc1CCCNC',
#  'C1cccccc1CCCOONNCNN',
#  'C1cccccc1CCCCC',
#  'CCCCCCCCCCCCCCCCOOO',
#  'C[C@@H]CCCCCCCCCOOOOOOOOOCCC',
#  'Cc1ccccc1CCCNOOOO',
#  'C[C@@H1]CCOOOCCOCCCCCCCCCCOOOOOO',
#  'CCOCC=CCCCCCCCCCCCCO',
#  'c1ccc(cc1)COOOOCOOOOOOOC',
#  'C1ccccc(c1)CCCCCCCCCCCCCCC',
#  'CCCC(CC)CCCCCCCCCCOOOOO',
#  'c1cccccccCCCCCC1',
#  'c1ccc(cc1)CC(=O)CCCCCCCCOOOO',
#  'CC1CCCC1CCCCCCCCC',
#  'CCCCCOOCCCCCCCCCCC',
#  'CC1=cccccccccc1NN',
#  'CNCCCCCCCCCCCCCCCCOCO',
#  'CC(COOO)OOOOO(ONNNNNN)',
#  'C[C@@H]1CCcccccc1CCCCCCCCCCCCCCCC',
#  'CC1CCcC1CCCCC',
#  'CC(C)CCCCC(CCCCCCCCCCCCCC)',
#  'c1ccc(cc1NCCCCC2)cccccccccc2',
#  'Cc1cccccc12NNC22cccc2',
#  'c1ccc2c(c1)ccccccnnnnnnC2C',
#  'CCCCCCCCCCCCCCCCCCCCCOOO',
#  'COc1ccccc1CNNCCCC',
#  'C[C@@H]CCCCCCCCCCCCCONN',
#  'CCCCCCCCCCCCCCCNOOO',
#  'CCOC(OOCCCCCCCCCO)C',
#  'CCOC(=O)CC1CCCC1',
#  'CCCCC=CCCCCCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCOOOOOO',
#  'CNNCCNCCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCC',
#  'C1cccccc1CCCOONC',
#  'CCCC1ncccccnnC1CCCCC',
#  'c1ccc(cc1)CCCCCCCCN',
#  'CCCCCCCCCCCCCCCCCCCCOOOOCC',
#  'CC1ccccccccCCC1',
#  'C1ccccc(c1CCCCCCC)OOOOO',
#  'c1ccc(cc1)CC(OOO)CCCCCCC',
#  'CC(C)CCCC1CCCCC1OOO',
#  'c1ccc(cc1CCCCCCCCC)F',
#  'CCCCCCCCCCCCCCCCCCCCCCOOOC',
#  'CCCCCCCCCCCCCCCCC',
#  'c1ccccccc1COCCCCCCCCC',
#  'c1cc(ccc1CCCOOONNCCC)',
#  'CCCCCCCCCCCCCCCCCCO',
#  'CCOc1ccccccccc1OOO',
#  'C1NNCCC1CCCCCCCCCCCCCCCCCC',
#  'Cc1ccccccccccc1CCCCOOOCCC',
#  'CCOC(OO)CCCCCCCCCCCCCCC',
#  'c1ccc(cc1)COOOCCCCCCCCCCCCCC',
#  'Cc1ccc(ccnc1CCCCC)CCCOOOO',
#  'C1cccccc1NCOOOOCCCCCCC',
#  'c1ccc(cc1)CCCCCCCCCCOOOOOOOO',
#  'C[C@@H]CCCCCCCCCOOOOOOOO',
#  'Cc1ccnnnn1CCCCCCCCCCCCCCOOOO',
#  'CCCCCCc1cccOO1',
#  'CC1CCCC1CCCOOCOOO',
#  'C[C@@H]CCCCCCCCCCCCCC',
#  'CC(C)CCCC1OOcccc1O',
#  'Cc1cccnnn1CCCCCCCCCCCCCOCC',
#  'C[C@@H1]CCCCCCCCCCCCCOOOOOOO',
#  'CC1cccnnnnnnnC1=NN',
#  'C1ccccc(c1)CCCCCCCCCCCC=O',
#  'CCCC(=C)c1ccnnnn1N',
#  'CCOc1ccccccccc1OOOOOOO-C',
#  'CC1CCOOcCCCCCC1',
#  'CCCCCCCCCCCCCCCCCOC',
#  'c1ccc2cc1CC2NNCCCCCCCCCC',
#  'c1ccc(cc1)CCCOOCCCCCCCCCOO',
#  'CC1cccccccc1CCCCCCCCCCCCCC',
#  'Cc1cccc2cc1ccccnnnnnnnnn2',
#  'c1ccccccccccc1BB',
#  'CCCCCCCCCCCCCCCCCCCCCCC',
#  'CC1cOcccccccccc1CCCCCCCN',
#  'C1cccccc1CCNNCCCCCCCC',
#  'c1ccc(cc1)CCCCC2ccCCCCCC2N',
#  'CC1CN(C1CCCCCCCCCCCCC(CC))',
#  'CCCCCCCC1cccccc1',
#  'Cc1ccccccc1CCCCCNNN',
#  'Cc1ccccccccccccc1OOOOCC',
#  'C1CCCCCC1CCCCCCCCCCCCCOOOOCCCCCO',
#  'c1ccccccc1CCCCCCCCCCCO',
#  'CCCCCCCCCCCCCCCCCCCCO',
#  'c1ccCCc1CCCCCCCCCCCCCCOOCC',
#  'CC1cccccccccccc1',
#  'COOC1OccCcC1CCCC',
#  'Cc1ccccc1NNNOCCCCCCC',
#  'Cc1ccccccc1CCCCC(NN)',
#  'CCOC(=O)CCOOCCCCCCCCCCCCO',
#  'CC1CC(cccc1)CCCCC',
#  'C[C@@H](CCCCCCCCCCCCCCC)CCC',
#  'CCCCCCCCCCCCCCCCCC',
#  'CCCCCNCCCCCCCCCC',
#  'CCCCOONNNNN(OCOOOCCCC)',
#  'c1ccc(cc1)CCCCCCCCCCCCO',
#  'Cc1cccccccccccccccSS1',
#  'CC1ccccccccNN1OOCCCCCCCC',
#  'c1ccccccc1CCCCCCCCCCCCC',
#  'C[C@@H]CCCCCCCCCCCCCCCCCCCCCCOOOOOOO',
#  'CCCCCCCCCCCCCCCCCCCOOO',
#  'c1ccc2c(c1)n(nnnnnnnnnn2CC)',
#  'c1ccc(cc1)NCOOONNNNNNNN',
#  'C[C@@H]1cccccc1CNN',
#  'C[C@@H]CCC(CCCC)CCCCC',
#  'C[C@@H]Cc1ccccc1OOO',
#  'CCNCNNCCCCCCNN',
#  'CCN=NNCCCCCCNNNCCCCCCOOO',
#  'CCCCCCCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCCCC',
#  'C1cccccc1CC=SOOOOO',
#  'CCC=CCCCCCCCCCCCCCCCCCCCC',
#  'c1ccc(c(c1CCCCCCCCCCCC))C-CCCCC',
#  'c1ccc(cc1)CCCCCCCCCCCCCCCCCCCCCC',
#  'CCOCC=NCCCCCCCCC',
#  'CC(C)CCCCCCCCCCCCCCC',
#  'c1ccc2ccc1cccCN2NN',
#  'C1CCCCC1CCCCCCCCCCCCCCCCC',
#  'c1cc(ccc1CCCOO)CCCCCC',
#  'CC(CCCCCCCCCCCCCCCCCCCC)',
#  'CC1C(CnnC1CCCCCCCCCCCCCCCCCC)C',
#  'c1ccc(cc1)CCCON2cccccccc2',
#  'c1cc(ccc1CCCCCCC)',
#  'CC(CCCCCCCCC)CCCOOOOOOO',
#  'C1cccccc1BBBBO',
#  'C1cccccc1CCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCOOOO',
#  'C1cccccccc1CCCCCOOOOOOOOO',
#  'CCCCCCCCCCCCCCSSOOOO',
#  'Cc1ccccccc1CCCCCCCO',
#  'c1ccc(cc1)CCOOOONN2cccccc2',
#  'Cc1cnnnnn1CCCCCCCCCC',
#  'C1ccccc(c1)CCCCCCCCCCCCCCOOO',
#  'CCCCCCCCCCCCCCCCCCCCN',
#  'c1cc(ccc1CCCCCCCCC)',
#  'c1ccc(cc1)CCCCCCCCC',
#  'c1ccccccc1CCCCCON',
#  'C1CCC(CC1)CCCC=CCCCC',
#  'c1ccc(cc1)CCOOOCCCOOOOOO',
#  'CC(C)CCCCCCCCCCCCCCCCCON',
#  'COc1ccccc1CCCCCCCCN',
#  'c1ccccccc1CCCCC',
#  'CCOC(=O)C1cccccc1',
#  'C[C@@H]1CCcccccc1CCCOOOO',
#  'c1ccccccc1CCCCCCCCCCCCCCC',
#  'CCNCNNNCCCCCCCCCCCCOOO',
#  'CCOCCOOCCCCCCCCCCCC',
#  'c1ccccc1CCCCCCC',
#  'C1cccccc1CCOOOONN',
#  'CCCCNCCCCCCCCCCCF',
#  'CC1cccccc1BBB',
#  'Cc1ccccccccccccc1NNS',
#  'C[C@@H]CCCCCCCOCCCCCCCCCCCCCCC',
#  'Cc1ccccccc1CCCCCCCCCN',
#  'CC(CCCCCOCOOOCOOOOOO)B',
#  'c1cnnoon1CCBNNNN',
#  'CCCCOCCCCCCCCCCCCCCCCC',
#  'c1ccccccc1CCCCCCCCCCCCCCOO',
#  'CCCc1ccccccccc1',
#  'Cc1ccccc1CCCOCOOCCCCCCC',
#  'CCCCCCC1CC1CCCC',
#  'Cc1cccnnnncccccc1NNSOOO',
#  'c1ccc(cc1)c2cccoon2OOOON',
#  'c1ccc(cc1CCCCCCCCCCCCCC)CC',
#  'c1ccc(cc1CC=O)OOCCCOOOOO',
#  'c1ccc(cc1CCOOOCCCCCOOOO)',
#  'CC(C)CCC(C)CCC1cccccc1',
#  'CC(C)CCCCOOOOCOOOOCCCB',
#  'C1CCcccccc1CCCCC',
#  'C1cccccccccccc1',
#  'C1cccccc1CCCCCCCCCCC',
#  'CCCCCCCCCCCCCCC',
#  'CCOC1cccccccccc1CCCC',
#  'CC1cccccccccccc1OCCC',
#  'C1NCCCC1CCCCCCCC',
#  'c1ccc(cc1)CCOOOCCCOCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCCCCCO',
#  'c1ccccccc1CCCCCCCCCCCCCCO',
#  'C1cCCCCC1CCCCCCCCl',
#  'Cc1cccccn1BBCCCCNNN',
#  'c1ccccc(cc1)CCCCCCCCCCCCCCCC',
#  'CC1ccccc1(BC)O',
#  'CCCCCCCCCCCCCCCC',
#  'Cc1cccccccccnnn1CC',
#  'C[C@@H]CCCCCCCCCCCCCCCCCCC',
#  'CCCCOOOc1ccccccc1OOO',
#  'CC1cccccccc1CCCCCCCCC',
#  'CCNNNCCCCCCCCCCCCCCOOCOO',
#  'c1ccc2ccc1cccccccccCCCCC2',
#  'c1ccc(cc1)CCCCCCCCCCCCCCCCC',
#  'CC(C)CCCC1OOOCC1OCCCCCCC',
#  'Cc1ccccccc1BNN',
#  'CCCCCCCCCCCCCCCCCCOCCC',
#  'C1ccccc(c1)CCCCCCCOOOOO',
#  'C1cc(nno1CCCCCCCS)',
#  'C1cccccc1SSCOOOOOOOOOCC',
#  'CCNC(=C)CCCCCCCCCOOOOO',
#  'CC1cccccccc1CCCCN',
#  'COOc1ccccc1OCCCCCCCCCCCC',
#  'CN(CCCCCCC)OCCCCOOOOOO',
#  'CCCCOOCCCCCCCCOOOC',
#  'CNCCCCCCCCCCCCSS',
#  'c1CCCCCC1C(CC)CC2CCCC2',
#  'C1cccccccc1CC',
#  'c1cc(ccc1)BBBB',
#  'C1cccccc1CBOSNN',
#  'CCOC(=O)c1cccc(c1)CCCCCCC',
#  'CC1CCCCcccccccccccc1',
#  'Cc1c(cccc1BBBC)NNN',
#  'Cc1ccccc1NCNNCCCCCCCCCCC',
#  'C[C@@H]1CccccccccccC1OOOO',
#  'CC1NCCC1CCCCCCCCCCCCCCCCCCCO',
#  'CC1Ccc(c(c1))COOOOOO[C@@]CC',
#  'c1ccc(c(c1)OOSSCC)OOOOOON',
#  'CC(C(CCCCCCCCCCCC))CCCCCCCCCC',
#  'c1ccccccc1CCCCCCCCCCC',
#  'C1cccccc1CCCCCCCCCCCCCCOOCC',
#  'c1cccccccccccC1B',
#  'CCOC1OOcCcccccccccccc1CO',
#  'CCCCCCCCCCCCCSSSOOOOO',
#  'c1cc(ccc1NCCCCCCC)N',
#  'CC(CCCCCCCCCCCC=CCC)CCCCCCC',
#  'C[C@@H]CCCCCCCCCCCCCCC',
#  'c1cccCC1CCNSSS',
#  'Cc1ccccccccccc1COOOO',
#  'Cc1cnnnnn1CC2CCCC2',
#  'C[C@@H]CCCCCCCCCCCCO',
#  'CCOC(OO)CCCCCCCONCCCCC',
#  'c1ccc(cc1CCCCCCCCCCCCCCCCC)',
#  'c1ccc(cc1)CCCCCCCCCOO',
#  'CC(CCCCCCCCCCCCC)O',
#  'CCOC(=O)CCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCCCCCCC(C)C',
#  'c1cc(ccc1CCCOO)CCC',
#  'C[C@@H]CCCCCCCCCCCCOOOOO',
#  'c1ccccccc1CCCCCCCCOOOO',
#  'c1ccccccc1BBNN',
#  'c1ccc(cc1)COOOOOOCOOOCCCCCCCCC',
#  'CCOC(OO)C1CCCCC1',
#  'C1cccccc1CCCCCCCCCCCOOOO',
#  'CCOC(=O)CCCCCCCC',
#  'CCCC(OC)c1ccccc1',
#  'Cc1cccccn1CCCCCCCCCCCCCCOOO',
#  'CC(C)CCC(C)=CCCCCCCCCCCOO',
#  'c1ccccccc1OOOOOOOCCCCCCCCCCO',
#  'CCOC(=O)CCCCCCCCCCCCCCCCCC',
#  'Cc1cccnnnccccc1',
#  'CC1cccccccccccccccccc1',
#  'c1ccccccc1SSBCB',
#  'CCCCCCCCCCCCCCCCOOOOOOO',
#  'Cc1ccccccccccc1BN',
#  'CCCCCCCCCCCCCCCCCCCO',
#  'c1ccc(c(c1)CCCO)CCCCCCCCl',
#  'c1cccCcc1CCCCCCCCCOOOOOO',
#  'CC1cccccccccccccccc1OO',
#  'C[C@@H](CCCCCCC)CCCCCCCCCC',
#  'CCOC(=O)CCCCCCCCCCCCCCOO',
#  'CCOc2ccccccc2CCCCC',
#  'CCNCCCCCCCCCCCCCCCCOOOOO',
#  'CN(C(O))c1ccccc1',
#  'CCCCCCCCCCCCOONCCCCC',
#  'Cc1ccccccccccc1CCC',
#  'C[C@@H]CCCCCCCOOCCCCCCCCCCCC',
#  'c1ccc(cc1)CCCCCCCCC2cccccccc2',
#  'c1ccccccc1COCCCCCCC',
#  'CCOC(OO)CCCCCCCCCC',
#  'C1cc(cnn1SSSSOO)CCCCCCC',
#  'C1ccccccccccnnn1BNNN',
#  'CCCCCCCCCCOOSSSSOOOOO',
#  'c1ccccccc1CCCCCCCCCC',
#  'c1ccccccc1NCCCCCN',
#  'CC(C)=CCCCCCCCCCCCOCCCCCCCCC',
#  'CCNCCCCCCCCCCCNCCCC',
#  'CC1ccccccccccC1CCCCCC',
#  'CCCCCNOCCCCCCCCCCCC',
#  'C[C@@H]CCCCCCCCCCCCCCN',
#  'Cc1ccccccc1CCCCCCCCCCC',
#  'c1ccc(cc1CCCN)NCCCCN',
#  'Cc1ccccccccccc1CNC',
#  'c1ccc(c(c1CCC))CCCCCCOOO',
#  'CNNCCCCCCCCCCCCCCCCCC',
#  'CCCCCCCCCC(C(S))',
#  'CCCCCCNCCCCCCCCCCC',
#  'c1ccccccc1COOCNNNCCC',
#  'CCOC(=O)CCCCCCCCCOO',
#  'c1ccccccc1CCCCCCCN',
#  'CCCCCCCCCCCCCSCC',
#  'c1ccccccc1CCOOONN',
#  'CCOC(=C)CCCCCCCCCCC(CCCN)',
#  'c1ccccccc1CNNCCCCC',
#  'Cc1ccccnn1CCCCCCCNN',
#  'CC(C)CCCCCCCCCCCCCCCCC',
#  'c1ccc(cc1)NCOONCCCCCCCF',
#  'CCCCCOCCCCCCCCCCCCCCOO',
#  'CCCCCCCCCCCCCCCCCCCNN',
#  'C[C@@H]CCCCCCCCCCCCCCCCOOOOCN',
#  'C[C@@+]CCCCCCCCCCCCC',
#  'c1ccccccc1CCCNNNNN',
#  'CCCC1nccccc1NNNN',
#  'Cc1ccccccccccccccccc1',
#  'C[C@@H]CC2cccccccccccccccc2/OO',
#  'c1ccccccc1CCCCCCCCCCCOO',
#  'CNCCCCCCCCCCCCCCCCCO',
#  'CCC=CCCCCCCCCCCCCOOO',
#  'Cc1ccccccc1CCCCCOOOOO',
#  'CCNCCCCCCCCCNSCOO',
#  'CC(c1ccccccccc1O)CC',
#  'CC1Ccccccc1CCC',
#  'c1ccccccc1CCNNCCCCCCCC',
#  'c1ccc(cc1CNOOOOO)CCCCCCCCC',
#  'CCCCC=NCCCNNNS',
#  'CNCCCCCCCCCCCCCCCCCCCCOOO',
#  'Cc1ccccccccccc1CCCCCCCCCCCCCC',
#  'C[C@@H]CCCCCCCCCCCCCCCCCCCC',
#  'CNCCCCCCCCCCCCCCOOO',
#  'Cc1ccccnn1CCCCCCCNC',
#  'Cc1ccccccccccc1CCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCCCCCCN',
#  'c1ccccccccccc1',
#  'Cc1ccccc1CCCNCCNNCCCCCO',
#  'C[C@@H](CC)NNNc1cccccCCC1',
#  'C1cccccc1BBBBOO',
#  'CC1c(ccc1CCCCCCCCCCC)CCCCCCC',
#  'CC1cccccccc1CCCCCCCCCONN',
#  'c1ccccccc1CCCCCCCCOOOOOO',
#  'Cc1cNcnn1CCCCCCCCCCCC',
#  'c1ccccccc1CCCCCCOOOOO',
#  'C[C@@H]1CCCCC1CCCCCCCCCCCCOOOOO',
#  'C[C@@H]CCCCCCCCCCCCCNN',
#  'CCCCOCCCCCCCCCCCOOOOO',
#  'CCCCCCCCCCOCCCCCOOOO',
#  'C1cccccc1CNNCCOOO',
#  'CCNCCCCCCCCCCCCCCCCO',
#  'Cc1cc(ccc1)SNOOO',
#  'COc1ccccccc1OOOOO',
#  'CC(C)CCCC1CCCSSS1OOOO',
#  'c1ccc(cc1)CCCCCCCC',
#  'c1ccc(cc1)CCCC=CN',
#  'C1cccccc1CCCCCCCCCC',
#  'Cc1ccccccccccc1OOO',
#  'CCCCCCCCCCNOOCCCCCCCC',
#  'CC(C(=O)COONNNCCOOO)OCCCCC',
#  'CCCCCCCCCCCCCCCCCCCCCC',
#  'c1cc(ccc1)S=NNN',
#  'CC(C)CCCCCOOOCCCCCCCCCCOO',
#  'CCCCCCCCCCCCCCCCCCCCC=COOOO',
#  'C[C@@H]1CccccCc1CCCCCCC',
#  'CC1CCCCCC1CCCCCCCCC2cccc2',
#  'CCCCCCCCCCCCCCCCCCCCCCCF',
#  'CC1cccccc1OOOCCOOOOCCCCCCC',
#  'c1ccc(cc1)CCCCCCCCCCCC',
#  'c1cCCCC1CCCCCCCCCCCCOCO',
#  'CNCCCCCCCCCCCCCCCCCCOOOO',
#  'C1ccccc(ccc1(CCCCCCCOO))C',
#  'c1ccc(cc1)CCCCCCCCCC2cccccc2CCO',
#  'Cc1ccccccc1CCCCOOCOO',
#  'CCOC(=O)CCCCCCCCCCCCCCCCCCCOCO',
#  'Cc1ccccccc1CCCCCCCOCOOO',
#  'C1cccccc1CCCCCCCCCCCCCCC',
#  'c1ccccccc1NOOOOOOO',
#  'C1cccccc1CCCCC=CCCCC',
#  'c1ccccccc1CCCCCCCCCCCCCCOOOO',
#  'CCCCCCCCCCCCOOOO',
#  'CCNC(=CCCCc1ccccc1)',
#  'c1cccnnn1CCCCC2CCCC2',
#  'c1ccccccc1CCCCCCCCCCOOO',
#  'CCCCCCCC(C)CCCCCC1cccc1F',
#  'CCCCCCCCCCCCCCCCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCCCCCN',
#  'CCCCOOOCCCOCCCCCCCCOOONCC',
#  'C1cccccccccccccc1OOOOOCCCC',
#  'CCCCCCOCCCCCCCCC',
#  'c1ccc(cc1)CCCCCCCCNN',
#  'c1ccccccc1CCCCCCCCCCCNN',
#  'c1ccc(cc1)CCCNNNCCCCCCCCCC',
#  'C1cccc(cc1)CCCOOCCCCCCC=O',
#  'C[C@@H]CCCCCCCCCCCCCCCCCCCOO',
#  'c1cccCcc1CCCCCNCCC',
#  'c1ccccccc1BBBNONN',
#  'C[C@@H]CCCCCCCCCCCCC',
#  'c1ccccccc1CCCC',
#  'c1ccccnn1CC(=O)CCCCCCl',
#  'CC1CCCC1CCC(OOCCCC)CCCCCCCCl',
#  'CNN=NCCCCCCCCCCCOOO',
#  'CC1cccccc1CCCCCCNN',
#  'C1CCCCC1CCCCCCCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCO',
#  'Cc1ccccc1NCCOCCCCCCCCCCCC',
#  'c1ccccccccccn1',
#  'c1cc(ccc1)NNNNNNNNNN',
#  'C1cccccc1CCCCCCCCCCCCCOOOO',
#  'c1ccc(c(c1))CCCCNO',
#  'CCCCNNCCCCCCCCCCCCC',
#  'CC1COccccccccC1COCOOO',
#  'C1cccccccccccc1CNNN',
#  'Cc1ccccccc1SSS',
#  'c1ccc(cc1)CCCCCCCCCN',
#  'Cc1ccccccc1NNCCCOOOOOCCC',
#  'CCCCCCCCCCCCCCCCCCCCCCCCC',
#  'c1ccc(ccc1)2BBB2',
#  'c1ccccccc1CCOOONCCCCCCCC',
#  'C1cccccc1NNNOOOOO',
#  'C1cccccccc1CCCCCCCCOO',
#  'CC1cccccccc1CCCOCCCN',
#  'c1ccccccc1CCCCCCCC',
#  'CCOCOOOCCCCCCCC',
#  'Cc1ccnnnn1CCCCCCCCCCCCCCCO',
#  'c1cc(ccc1CC(O))CCC',
#  'CCSCNNCCOC(COCNNOOOO)',
#  'CNCCCCCCCCCCCCCCCCC',
#  'c1ccccccc1NNCCCCNN',
#  'CNCCCCCCCCCCCCCCCCOOCCCO',
#  'Cc1ccccc1SSSSSS',
#  'c1ccccccc1CNCCCCCCCCOOO',
#  'CCCCCCCCCCCCCCCCCCCCCCCCCCCCOOOO',
#  'c1ccc(cc1)CCCCCCCCCCCCCC',
#  'CC1cOcccccccccc1OOOO',
#  'CCCCC(CCCCCCCCCC)CCCCCCCOCOCO',
#  'Cc1ccccccc1CCCCCCCCO',
#  'Cc1ccccc1CCCCOOOOCCC[C]',
#  'c1ccc(cc1)CCNNNNCNNCCCC',
#  'CC(C)CCCCCCCCCCCCCCCCCC(C)',
#  'CCCCCNCCCCCCCCCCC',
#  'c1cc(Cc1CCCCCCCCCCC)O',
#  'c1ccccccc1CCCCCCCCCCCC',
#  'C[C@@H]CCCCCCCCCCCCCCCCCCCCCCCCCCC',
#  'c1cc(ccc1)BOOOOO',
#  'CC1Cccccccn1CCCCNNN',
#  'Cc1ccccnccnnnnn1NNN',
#  'c1ccc(cc1)COOCCCCCCOOOO',
#  'c1ccccccc1CCCCCCCCCCCCOOOO',
#  'C1CCCCCCC1CCCCCCCCCCCCCCCCCCCCC',
#  'CC(C)CCCCCOCCCCCCCCC',
#  'CCOCC=CCCCCCCCCCCCOCCC',
#  'C1ccCCcC1CCCCCCC',
#  'CC(C)CCCOOOOSSOOOOOOONNOCNN',
#  'Cc1ccccccc1CCCCCCCCCNN',
#  'CCNCCNCCCCCCCCCCCCCCCCC',
#  'c1ccc(cc1)COOOONNCCCCCCCCOOOO',
#  'Cc1ccccc1BBOOOOOO',
#  'CCCCCCCCCCCCCCCCCCCC(O)OO',
#  'c1cc(ccc1)BBBBBBO',
#  'CC1CCCC1CCNNCCCNCO',
#  'CCCCCCCCCCCCCCCCO',
#  'C1cccccc1c2ccccc2',
#  'C1ccccnc1CCCOONNCCCCCCCC',
#  'Cc1ccnnnn1CCCCCCCC',
#  'c1ccccccc1CCNNN',
#  'c1ccc(cc1CCOOO)CCCCCOCOOO',
#  'c1ccc(cc1)CCCCCCCCCCCCCCCCCCCC',
#  'c1ccc(ccc1)2CCCC2',
#  'c1ccc2cc1cccccco2',
#  'CCCNNNNCCCCCCCCCCOOOOO',
#  'CCCCCCCCCCCCCCCCCCCCOOO',
#  'CCCCCCCCCC2CCCC2OOOOO',
#  'CC1CCCCCCCCCCCCC1',
#  'CCCC1cccccc1CCCCCCOOOOOO',
#  'c1ccccccc1CCCCCCCCCCCCOOOB',
#  'c1ccc2ccc1ccccccNccc2S',
#  'CCNCCCCCCCCCOCOOOOB',
#  'CCOC(OCCCCC)CCCCCCCCCCCCOOOO',
#  'c1cc(ccc1CCCO)NNCCCC',
#  'CCOCOCCCCCCCCCCCOOOO',
#  'CCCCCCCCCCCCCCCCOOOO',
#  'CCCCCCCCCCCCCCCCCCCOO',
#  'Cc1c(cco1)NNNSSS',
#  'C[C@@H]CCCOOOSSOOOCCC',
#  'CCc1ccccc1NNNN',
#  'C1CCCCCCCCCCCCC1CCCO',
#  'C1cccccc1NNOOOO',
#  'C[C@@H]1CCCCC1CCCCCCCCCOOO',
#  'CCCC1cccccc1CCCC',
#  'Cc1ccccccccccccc1CCCCC',
#  'CCOC(=O)CCCCCCCCCCCN',
#  'c1NcCCc1CCCCCCCCCC',
#  'CC1cccccccc1CCCCCCCCCOOOOC',
#  'CCCCCCCCOOOCCCCCOOOOO',
#  'CC1CCCC1CCCCCCCCCCCCCCCCC',
#  'CN1CCcccccccc1CCCCC',
#  'CC1cccccccccccccccc1',
#  'CCN=CCCCCCCCCCCCCCCCOOOO',
#  'c1ccccccc1CCCCCCCCCCOON',
#  'CC1CCCC1NNCCCCCCCCCCCCC',
#  'C1ccccccccnnnn1',
#  'c1ccccccc1CCCCCCCCOOOOOCCC',
#  'c1cccccccc2nnnn2CNN1',
#  'C1cccccccc1CCCCCCCCCCCCO',
#  'Cc1ccccccc1NN',
#  'c1ccccccc1CCCCCCCCOOOCCC',
#  'CCCC(=O)CCCCCCCCCCCO',
#  'c1ccc(cc1)SS(OOOO)OCCCCCC',
#  'c1ccc(c(ccccccc1))CCOOOOOOOO',
#  'c1ccccc(ccccCC1)NCCCCCCCCC',
#  'CC1CCCCCC1(CCCCCC)CCC',
#  'Cc1cc(cnn1)CCCCCCCCCCCCC',
#  'Cc1ccc(n(n1))CCCCCCCCCCCCC',
#  'c1ccc2ccc1cccCC2CCCOOOOO',
#  'c1ccccccc1CCCCCCCCCCCCOOOOO',
#  'CNNCNNCCCCOOONCC',
#  'c1ccc2c(c1)ccc32CCCCCCCCc4ccccc34',
#  'C1CCCC1CCCCCCCCCCCCCCCCCCCC',
#  'c1ccccnn1CC2OC2CI',
#  'c1ccccccc1CCOOONNCCCCCCC',
#  'c1ccccccc1CCCCCCNC',
#  'c1ccc2cc1cccccccc2',
#  'CCCC1nccccn1',
#  'CC1cOOOcccccccccccc1',
#  'CCCCCCCCCC1CCCNC1',
#  'CCOCOOOOCC=CCCCOOO',
#  'c1ccc(cc1)CCCCCCCO',
#  'c1ccc(cc1)CCCCNCCCCC',
#  'CCCCCCCCCCCCCCCCCCCOOOOO',
#  'C[C@@H]1CCNcccccccccc1COC',
#  'CC(C)CCCCCCCCCCCCCCCCCCCCCCCCCF',
#  'c1ccc(cc1)CCOOOOOCOOOO',
#  'CCCCOOOCCCOOOCCOOCCCCC',
#  'CC(C)CCCCC(OONNCCCCCCCCCCC)OO',
#  'Cc1ccc(nn1)CCC=CCCCCCCCCF',
#  'CCCCOCCCCCCCCCCCOOOO',
#  'c1ccccccccccccc1OOO',
#  'CCOCOOOCCCNNONNON',
#  'Cc1cccnnn1CCCC3CCCC3NOOO',
#  'C1cc(onn1)CCNNNC2CCCC2',
#  'CCOC(=O)CCCOOCCCCCCCCCCC',
#  'CCCCCCCCCCCC',
#  'C1cccccccccccccnOOOO1',
#  'c1ccccccc1SCCCCCC',
#  'Cc1cccccccccn1CC',
#  'CCCCCCCCCCCCCCCCCOOO',
#  'c1ccc(cn1)CCCCCCCCCCCCCCCCC',
#  'c1ccc2c(c1)cc3cccccccccc23',
#  'c1ccccccc1CCCCOOOCCOOCO',
#  'C[C@@H]CCCCCCCCCCCCCCOOOOC',
#  'CNNCCNCCCCCCCCCCCCOO',
#  'c1ccc(cc1)CNNCCC2CCCCCC2OO',
#  'CCCCCCCCCCCCCCCCCCCCCCCCCCC',
#  'CNNCCCCCCCCCCCCCCCC',
#  'Cc1c(c(nnn1))CCCCCCCCCCCCC',
#  'CCOC(=O)CC1Ccccccccc1',
#  'CCNCCCCCCCCCCCCCCCCCOOOO',
#  'CCOCOOCCCCCCCCCC',
#  'Cc1ccccccccccc1C',
#  'CCCCCCCCCCCCCCCCCCCCCCCC',
#  'Cc1ccccccccccccc1N',
#  'CCCCCCCCCCCCCCCCOOOOOOOO',
#  'CNCCCCCCCCCCCCCC',
#  'c1ccccccc1BCCCBB',
#  'C1CCCCC1CCCCCCCCCCCC',
#  'CCCCOCCCCCOOCCCCCCCCCCC=O',
#  'c1ccc(cc1)CCOOOCCCCCCCCC',
#  'c1ccc(cc1)c2ccccccccccc2',
#  'CCCCCCOCC1OOCCCC1CCCOONN',
#  'C[C@@H]CCCCOOCOCCCCCCCCCCCCCCCCCC',
#  'CC1cccccccccc1CCCC',
#  'C1cccccc1CCCOCCOOOOO',
#  'CCOC(=O)CCCCCCCCCCCCO',
#  'c1ccccccc1NCCCONCCC=O',
#  'Cc1ccccccccccc1CCCCCCCCCCCCC',
#  'Cc1cnnnnnnnnnnnnnnnn1',
#  'C1cccccc1CCOOOO',
#  'C[C@@H]CCCCCCCCCCCCCCNNC',
#  'CC(CCCCCCC)CCCCCCCC',
#  'C1cccccc1CCCNNNCCCCCCCC',
#  'C[C@@H]CCCCCCCCCCCCCCCCCCCCCC',
#  'c1ccccccc1CCCCCCCOOOO',
#  'CCCCCCCCCCCCCCCCCCCCOOOOOC',
#  'C[C@@H]CCCCCCCCCCCCCCCC',
#  'c1ccc(cc1)CCCCCCCCCCCOOOCCCOO',
#  'c1cc(ccc1)NNNCCCCN',
#  'CCOC(=O)C1CC(CC1CCC(F))',
#  'c1cc(ccc1CCCCCCCl)',
#  'c1ccccccc1COCCCCOOOOOOOO',
#  'CCOC(=O)CCCCCCCCCCC',
#  'CCOC1Occcc1CCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCOCCCOO',
#  'C1ccccc(c1)CCNNNCCC',
#  'C1cccccc1CCCCCCCCCCCCCC=COCCCC',
#  'c1ccc(cc1)CCOCCCCCCCCCCOOOO',
#  'CCCCOOOCCCCCCCCCCC',
#  'Cc1cccc2c1cccccccccc2',
#  'Cc1cncn2cccccccc21',
#  'CC(CCCCCCCCCCCCCCCCCCCCC)',
#  'CC1CCOCCCCCCCCCCCCC1',
#  'c1ccc(cc1)CCCCNCCCCCCCCCCCC',
#  'CNNNCCCCCCCCCCCCCCCOOOO',
#  'c1cc(ccc1NN(OO))C',
#  'Cc1ccccccccccc1',
#  'Cc1ccccccccc1CCCCCCCCCCCOOO',
#  'CC(C)CCC1cccccc1F',
#  'C1cccccc1SSSOOOOO',
#  'C1cccccccccccc1CCC',
#  'C[C@@H]CCCCCCCCCCCOCOOOCCCCC',
#  'c1cccccccccccC1',
#  'CCCCNNCCCCCCNNC',
#  'c1ccc2cc1C2CCSCCC',
#  'Cc1ccccc1NCNCOOONN',
#  'CC1CCOCCCCCCCCCCCCC1=O',
#  'Cc1ccccccc1CCCOOOO',
#  'C1cccccccccccc1CCCCCOO',
#  'C[C@@H]CCCCCCCCCCCCCOO',
#  'c1cc(ccc1)CCNNNCCCCCC',
#  'C1ccccc(c1)CCCCCNN',
#  'c1cccc(ccccccc1)NCCCCCCCCC',
#  'CC1ccnnnnn1SCCCCCCCCCCCCC',
#  'CC1cccccccccccc1BBB',
#  'Cc1cccnnccccnnnnNN1',
#  'CC1ccccccnnnnC1COON',
#  'CCOC(=O)CCCCCCCCCCCO',
#  'CC(CCCCCCCCC)C=CCCCCCCCCCCCCOOO',
#  'Cc1cccnOcccccccccccnnnn1',
#  'C1cccccc1CCCOOCCCCCCCCCCCC',
#  'CC1cOcccccccccc1CCCCC',
#  'CCOC(=O)c1ccccccc1CCCCCCCCCCCCCC',
#  'c1ccc(cc1)COOOOCCCCOOOO',
#  'c1cNC2C1CC22CCC2',
#  'Cc1c(c(nnn1))CCCCCCCCCCCCCCC',
#  'C[C@@H]CCCCCCCCCCCOOOOOO',
#  'Cc1ccccccccccccc1CCC',
#  'CCCCCCCCCCCCCCCCCCOCN',
#  'C1ccc2nn1nnnnnnC2CCCC',
#  'CCNCCCCCCCCCCCCCCCC',
#  'CCCCCCCCCCCCCCCCC=O',
#  'Cc1cnnnnn1SSSNNN',
#  'c1cc(c(cc1CC))CCCCCCC',
#  'C[C@@H](CCCCCC)CCCCCCCOOC',
#  'c1ccccccc1CCCCCCCCC',
#  'Cc1cnnnnn1CCCCCCCCCCCCCCCC',
#  'C[C@@H]CCCCCNCCCCCCCN',
#  'CCOCOOOCCCOOOCOOO',
#  'Cc1ccccccc1CCCC',
#  'CCOCCCCCCCCCCCCCCCCC',
#  'Cc1ccccccc1CCCCCCCCCC',
#  'c1ccc(cc1)CCCCNCCC',
#  'CCCCCCCCCCOOOCCO',
#  'Cc1ccccc1NNNBOOOO',
#  'c1ccccccc1SS(=S)OOOOOOO',
#  'CCOCCOOCCCCCCCCCOOOOOO',
#  'Cc1ccccccccccccccnn1SS',
#  'c1ccccccc1CCC(OOO)CCCC',
#  'c1ccccccc1CCCCCCCCCCO',
#  'c1ccc(cc1CCCOO)CCCCCOCC',
#  'c1ccc(cc1)CCCCCCCCCCCCCO',
#  'Cc1cccnnn1CCCCCCCCCCCCCCCCCCCCCC',
#  'Cc1ccccccc1NCCCCCCCCC',
#  'CCCCCCCCCCCCCCCS',
#  'Cc1ccc(cc1BSS(OO))OON2CC2',
#  'CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC',
#  'C[C@@H]CCCOCCCOOCCCCCC',
#  'COOc1ccccccccc1OOO',
#  'CCOC(=O)CCCCCCCCCCOOOOOO',
#  'c1ccc-c(c1CCCCC)CCCCCCCCCCOOO',
#  'c1ccccccc1CCCCSS',
#  'c1ccc(cc1CCCCCCCCOOO)',
#  'CCCCOOCCCCCCCCCOCCCCCCC',
#  'C1ccccccccccccccB1',
#  'c1ccccccc1CCOOOONCCCCCC',
#  'Cc1ccccccc1BBS',
#  'C[C@@H]CCCCCOCOOCCCCCC',
#  'c1ccCCc1CCCCCCCCOOOOO',
#  'C[C@@H]1cccccccccccc1OO',
#  'CCCCCCCCCCCCCCCCCCCCCCCCCCCCCOOO',
#  'c1ccc(cc1CCOOCCCO)OO',
#  'C1cccccc1n2nnnnnnn2CCCCN',
#  'CC(CCCCCCCCC)NNNOCCCCCC[HH]',
#  'CCOC(=O)CCCCCCCCCCCCCCCC',
#  'Cc1cccnnn1SS(=O)OO',
#  'CCOC(=O)CC1CNNN1',
#  'C1cccccc1CCCOOOOON',
#  'c1ccccccc1CCBCB',
#  'CCOC(=O)CCCCCCCCCCCCC',
#  'C1CCCCCC1CCCCCCCCCCCCCCC',
#  'c1ccc2ccc1ccccc2NNN',
#  'C1cccccc1CCCCCCCCCCCCCCOO',
#  'Cc1cnnnnnnnnnnnn1',
#  'c1ccc(cc1)c2ccccccccccccccc2',
#  'c1ccccccc1NN2CC2',
#  'CC(C)CCCCCCCCCCCCCCCCCCCCCCCC',
#  'CCOc1ccccccccc1OOOOO',
#  'CC(CCCCCCCCCCCCCC)OO',
#  'c1cCC(Co1CCCCC)CCCCCCCCCCC',
#  'c1ccccccc1CC2nnCCnccccnnnnn2',
#  'CCCCCCCCCCCCCCCCCCCCCCCCOO',
#  'CCOCCOOCCCCCCCCCOOOO',
#  'Cc1cccnncc1CCCC',
#  'CCOC1nncnn1CCCCCCCC',
#  'Cc1cccnnccccc3cccccn13',
#  'CCCCCCCCCCCCCCCOOO',
#  'Cc1cc(ccc1SSSS(OO))OOCCCCCC',
#  'C1cccccc1NNCCCN=NON',
#  'CCCCOOOCCCCCCCCCCCCCC',
#  'c1ccc(cc1)CCCCCCCCCCCCCOOO',
#  'CCCCCCCCCCCCCCCCCCCCCCOOOO',
#  'Cc1cccnnnnnnCC1CCC',
#  'Cc1ccccccccccccc1BB',
#  'C[C@@H]CCCCCCCCCCCCCOOOO',
#  'CCC1NNN1CCCC',
#  'C1cccccccccccc1CCCCCC',
#  'C[C@@H]CCCCCCCCCCCCOOOO',
#  'CCCCCCCCCCCCCCCCCOOOO',
#  'Cc1ccccccccccc1CCCCCOOOCCCCCCC',
#  'CCOC(=O)c1c2ccc21CC',
#  'C[C@@H]CCC=NNSOOO',
#  'c1cc(ccc1NCCOOOOOO)O',
#  'C1cccccc1CCCSSN',
#  'CCOC(=O)CCCCCCCCCCCCCC',
#  'C1ccccc(c1)CCCOOCCCCCCCCCC',
#  'CC1cOcccccccccc1BCN',
#  'C1ccccccccCCCC1CCCF',
#  'C1CCCCCC1CCCCCCCCCCCCCCCCCC',
#  'Cc1ccccc1CCCNCCCCCCCC',
#  'CCCCCCCCCCCCCCCCCCOO',
#  'CCOC(=O)c1ccnnnn1CCCCCC',
#  'Cc1ccccccc1NCCCCCCF',
#  'c1ccc(cc1CCCCCCCCC(OOO))',
#  'CC1COC(CC1OOO)OONNCCCCON',
#  'c1ccccccc1CCCCCCCCOOOOCCCCC',
#  'Cc1ccccccc1CCCCCCC',
#  'CCNCNCCCNCN(CCCCC)CCCC',
#  'c1cccnnn1CCCCC=CCCC',
#  'CCOC(=O)CCCCCCCCCCCCCCCNN',
#  'c1ccc(cc1)CCCCCCCCC2cccccc2',
#  'c1cc(coo1)CCCCC=CC',
#  'c1ccc(cc1)CC2nnnccccc2',
#  'c1ccc(cc1)C2ccccccccccOO2',
#  'Cc1ccccccccccc1NNCC',
#  'CCOCCOCCOCOOONN',
#  'CCC(CNN)CCCCCC',
#  'CCCC(CCCCCCCCCCCCCCCC)',
#  'CCCCCCCCCCCCCCC=CCC',
#  'c1ccc(cc1)COOC=CCCC',
#  'CCOC(=O)CCCC2CCC2CCCCCCCO',
#  'C1cccccc1NCCOOCCCCOOO',
#  'CCOC(=O)C1ccccC1CCOOOO',
#  'Cc1ccccc1CCCCC2nncccco2',
#  'CCC1cccccc1CCCCCCC',
#  'CCC1nnnnCC1CCC',
#  'CCCC1ccccccCCC1CCC',
#  'c1ccccccc1NCCCCCCN',
#  'C1CCCCCCCCCCCCCCCCC1OO',
#  'C1cccccc1CCCCNNCCCCCCCCO',
#  'C[C@@H]CCCCCCCCCCCOOOOO',
#  'c1ccCCc1CCCCCCCCCCS',
#  'c1cccnnn1C(CCCCCCC)',
#  'CCOCCCCCCCCCCCCCCCCCCCC[HH33]',
#  'c1ccccccc1CCCCCCCCCCCCNNN',
#  'CCOC(=O)CC1CCCCC1OOO',
#  'c1ccc(cc1)CCCCCCCCCCCCCOO',
#  'CCCCCCCCCC(CCCCCCCCCCCCCCCCC)',
#  'CCCC(CCCCOONNCC)CCCC',
#  'C1CCCCC1CCCCCCCOOCCCOO',
#  'C[C@@H]1cccccccc1CCC',
#  'CCCCCCCCC1OOOC1OOO',
#  'CCOC(=O)CCCCCCCCNN',
#  'C[C@@H]CCCOOCCCCCCC',
#  'C1cccccc1NCCNCNCCCCN',
#  'CCCC1cccccc1',
#  'CCCCCCOCCCCCCCCCCCCCCC',
#  'Cc1cccc2cc1nnnnnnnn2SSC',
#  'CC(CCCCCCCCCCCCCCCCCCCCOO)CCC',
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC',
#  'c1ccCCc1CCCNCCCC2cccccc2',
#  'CCCCCCCCCC(CCCC)OO',
#  'CCCCCCCCCCCCCNOOOOO',
#  'CCOC(=O)C1cccccccccc1',
#  'Cc1ccccccccccc1OOC',
#  'C[C@@H]CCCCCCCOOCCCCCCCC',
#  'C1cCccc(c1CCCCCC)NN',
#  'CCNCCCCCCCCCC=CCCCCCCCOOO',
#  'C[C@@H]1ccCCCC1CCCOOO',
#  'c1ccc(cccc1)BB',
#  'CCOC(=O)CCCCCCCCC',
#  'c1cc(ccc1)BSSSNN',
#  'CCCCCCCCCCCCCCCCCCCCCOO',
#  'CC1CCCC1CCCCCCCCCCCCCCCCO',
#  'CC1COOcccccccccccccc1CCCCC',
#  'CC1CCNN1NNNCCCCCC',
#  'c1cc(ccc1)SS=SSCOOOOO',
#  'CCCCCCCCCCOOOCCCCO',
#  'Cc1cccccccccnnnnCC1CCC',
#  'C1cccccc1NNNNC',
#  'c1ccccccc1CC(=O)CCCCCCS',
#  'Cc1c(nnn1SNCOCC)',
#  'CC1cccccccccccc1OOOOOOOO',
#  'CC1cccccccccccc1OOBBO',
#  'C1cccccc1CCCCCOOOCCCCC',
#  'c1ccccccc1CCCCCCCCCCCCCCOOOOO',
#  'CCCCCCCCCCCCCCCCOO',
#  'CC1cccccccccccccc1',
#  'CCCCC=CCCCCCCCCCOCCCC(CC)',
#  'Cc1ccccnn1CCCCCCCCCCCCCCCCCCC',
#  'c1cc(ccc1NN)COOOOCCC',
#  'CCCCCCOCCCCCCCCCCCOOO',
#  'c1ccc2cc1ccccccn2N',
#  'CC(C)CCCCCOOCCCCCCOOOO',
#  'c1cc(ccc1)CCCCCCCCCOOOOO',
#  'CCNC(CC)CCCCCNCCCO',
#  'COc1ccccc1BBBN',
#  'CCNCNCCCCCCCCCCCCC',
#  'Cc1ccccccccccccc1',
#  'CN1CCCC1CCCCCCCCCCOO',
#  'c1ccccccccccccc1NNN',
#  'C[C@@H]1CCCCCC1COOOO',
#  'c1ccc(cc1)C2cccccccccc2',
#  ...]

# %% [markdown]
# ### filtering the molecular within the interval [200, 220] and save the result in local path

# %%
all_smile = []

all_smile = list(set(valid_smile))

mw = np.zeros((len(all_smile)))

for i in range(len(all_smile)):
    s = all_smile[i]
    m = Chem.MolFromSmiles(s)
    mw[i] = ExactMolWt(m)

lines = []
for i in range(len(mw)):
    if (mw[i]>=200) and (mw[i]<=220):
        lines.append(all_smile[i] + "     " + str(mw[i]))

with open("./result/sampling/MW_condition_210.txt", 'a+') as f:
    f.seek(0)
    data = f.read(100)

    if len(data)>0 :
        f.write("\n")
    for line in lines:
        f.write(line)
        f.write('\n')
